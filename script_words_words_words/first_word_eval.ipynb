# %% [markdown]
# This notebook calculates the distribution of words over different word categories.

# %%
import nltk
import pickle
import torch
import pandas as pd

from nltk.corpus import stopwords

#lists taken from the attention parser also used to evaluate model performance
position_words =['right', 'left', 'top', 'bottom', 'middle', 'mid', 'front', 'closest', 'nearest', 'center', 'central',
                               'corner', 'upper', 'back', 'far', 'leftmost', 'lower', 'low', 'rightmost',
                               'farthest', 'furthest', 'next', 'last', 'up', 'above', 'below', 'down', 'side']


color_words = ['white', 'green', 'blue', 'red', 'yellow', 'black', 'brown', 'pink', 'dark', 'darker', 'orange',
                            'gray', 'purple', 'beige', 'bright']

size_words = ["big", "bigger", "small", "smaller", "tall", "taller", "large", "larger", "little", "short", "shorter",
                           'tiny', "long", "longer", 'huge']

rel_pos_words=['above', 'about', 'below',"behind" 'beneath', 'beside', 'between', 'by','against', 
               'from', 'through', 'under', 'underneath', 'with','near', 'inside', 'from']

# %%
def load_data(model,mode, dataset, split):
#load predicted and gold bounding boxes

    try:

        #the predicted bounding box
        with open(r"/home/users/fschreiber/project/bboxes_"+model+"/"+dataset+"/"+split+"_pred_bbox_list.p","rb") as f:
            pred_bbox_list=list(pickle.load(f))

        if mode=="non_inc":
            #the target bounding box
            with open(r"/home/users/fschreiber/project/bboxes_noninc_"+model+"/"+dataset+"/"+split+"_pred_bbox_list.p","rb") as f:
                target_bbox_list=list(pickle.load(f))

        elif mode == "inc":
            #the target bounding box
            with open(r"/home/users/fschreiber/project/bboxes_"+model+"/"+dataset+"/"+split+"_target_bbox_list.p","rb") as f:
                target_bbox_list=list(pickle.load(f))
        else:
            print("The mode can only be non_inc or inc")
            return -1,-1,-1,-1,-1

        #the number of one sentence split up incrementally ("the left zebra" would have length 3)
        with open(r"/home/users/fschreiber/project/incremental_pickles/length_incremental_units/"+dataset+"_"+split+"_length_unit.p","rb") as f:
            inc_len=pickle.load(f)

        #the original model data split up incrementally
        data_model=torch.load("/home/users/fschreiber/project/ready_inc_data/"+dataset+"/"+dataset+"_"+split+".pth")

        with open(r"/home/users/fschreiber/project/binary_grouped/"+model+"/"+mode+"/"+dataset+split+".p","rb") as f:
            binary_grouped=pickle.load(f)

        
        if mode=="non_inc":
            target_bbox_list=[x for x,y in zip(target_bbox_list,inc_len) for _ in range(y)]
            
        if model=="TVG":
            pred_bbox_list,target_bbox_list=TVG_prep(pred_bbox_list,target_bbox_list)
                    

        return pred_bbox_list,target_bbox_list,inc_len,data_model,binary_grouped
    
    except FileNotFoundError as e:
        #print(e)
        
        return  -1,-1,-1,-1,-1
    


#TVG needs some extra adjustments to fit the same data format as Resc
def TVG_prep(pred_bbox_list,target_bbox_list):
    #print("TVG")
    for ind,(pred,targ) in enumerate (zip (pred_bbox_list,target_bbox_list)):

        pred=pred.view(1,-1)

        pred=xywh2xyxy(pred)
        pred=torch.clamp(pred,0,1)

        pred_bbox_list[ind]=pred

        targ=targ.view(1,-1)
        targ=xywh2xyxy(targ)

        target_bbox_list[ind]=targ
    return pred_bbox_list,target_bbox_list

#copied from TransVG needed to transform the bounding box vectors
def xywh2xyxy(x):
    x_c, y_c, w, h = x.unbind(-1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=-1)

# %%
pred_bbox_list,target_bbox_list,inc_len,model,binary_grouped=load_data("ReSc","inc","unc","testB")

# %%
#group sentences that belong to one incremental unit
def group_by_increment(bbox_list,inc_len):
    counter=0
    group_list=[]
    for i in inc_len:
        
        group_list.append(bbox_list[counter:counter+i])
        counter=counter+i
    return group_list

model_group=group_by_increment(model,inc_len)

# %%
#helper function to make code more readable 
#calculates the ratio of stop,position,color and size words 
#to all words in the first position

def calculate_ratios(stop, position,color,size, rel_pos, rest, first_words):
            
                all_words=len(stop)+len(position)+len(color)+len(size)+len(rel_pos)+len(rest)
                
                stop_ratio = round(len(stop) / all_words, 2)
                pos_ratio = round(len(position) / all_words, 2)
                color_ratio = round(len(color) / all_words, 2)
                size_ratio = round(len(size) / all_words, 2)
                rel_pos_ratio = round(len(rel_pos) / all_words, 2)
                rest_ratio = round(len(rest) / all_words, 2)
                
                return stop_ratio, pos_ratio,color_ratio,size_ratio,rel_pos_ratio, rest_ratio

# %%
# A set of functions to get change words

#checks if a word triggers change 
def get_change_words(model_group, mixed_values, mixed):
   
    change_right = []
    change_wrong = []

    #Change can only happen on mixed values
    for entry, indi in zip(mixed_values, mixed):
        for i in range(len(entry) - 1):
            m = model_group[indi]
            
            #if the result stays the same, pass
            if entry[i] == entry[i + 1]:
                pass
            
            #if the object is found mark right change
            elif entry[i] == 0 and entry[i + 1] == 1:
                change_right.append(m[i + 1][3].split()[-1])
            #if object is lost mark wrong change
            elif entry[i] == 1 and entry[i + 1] == 0:
                change_wrong.append(m[i + 1][3].split()[-1])
            else:
                print("Something is very wrong.")
    return change_right, change_wrong

#split words into word lists
def split_change_words(word_list):
    stopwords_english = stopwords.words("english")

    # Split words by word category
    position = [i for i in word_list if i in position_words]
    color = [i for i in word_list if i in color_words]
    size = [i for i in word_list if i in size_words]
    rel_pos = [i for i in word_list if i in rel_pos_words]
    stop = [i for i in word_list if i in stopwords_english]
    rest = [i for i in word_list if i not in stopwords_english and i not in position_words and i not in color_words and i not in size_words and i not in rel_pos_words]

    return stop, position, color, size, rel_pos, rest


#A function to find change words by word category
def change_words(binary_grouped, model_group):
   
    stop_wrong, pos_wrong, rest_wrong, color_wrong, size_wrong, rel_pos_wrong = ([] for i in range(6))
    stop_right, pos_right, rest_right, color_right, size_right, rel_pos_right = ([] for i in range(6))

   #split entries by condition
    right_only = []
    wrong_only = []
    mixed_only = []
    mixed_values = []
    for index, entry in enumerate(binary_grouped):
        if all(p == 1 for p in entry):
            right_only.append(index)
        elif all(p == 0 for p in entry):
            wrong_only.append(index)
        else:
            mixed_only.append(index)
            mixed_values.append(entry)

   #get the words triggering change in the mixed conditions
    model_group = group_by_increment(model, inc_len)
    change_right, change_wrong = get_change_words(model_group, mixed_values, mixed_only)

    all_entries = [change_right, change_wrong]
    types = ["change_right", "change_wrong"]

    # Loop through the lists of change words and calculate ratios for each word category
    for lst, typ in zip(all_entries, types):
        stop, position, color, size, rel_pos, rest = split_change_words(lst)
        stop_ratio, pos_ratio, color_ratio, size_ratio, rel_pos_ratio, rest_ratio = calculate_ratios(stop, position, color, size, rel_pos, rest, lst)

        if typ == "change_wrong":
            stop_wrong.append(stop_ratio)
            pos_wrong.append(pos_ratio)
            color_wrong.append(color_ratio)
            size_wrong.append(size_ratio)
            rel_pos_wrong.append(rel_pos_ratio)
            rest_wrong.append(rest_ratio)
        elif typ == "change_right":
            stop_right.append(stop_ratio)
            pos_right.append(pos_ratio)
            color_right.append(color_ratio)
            size_right.append(size_ratio)
            rel_pos_right.append(rel_pos_ratio)
            rest_right.append(rest_ratio)

    # Organize the ratios into lists for different word categories
    pos_all = [pos_right, pos_wrong]
    color_all = [color_right, color_wrong]
    size_all = [size_right, size_wrong]
    rel_pos_all = [rel_pos_right, rel_pos_wrong]
    stop_all = [stop_right, stop_wrong]
    rest_all = [rest_right, rest_wrong]

    return pos_all, color_all, size_all, rel_pos_all, stop_all, rest_all

change_words(binary_grouped, model_group)
# Out:
# ([[0.62], [0.24]],
#  [[0.02], [0.04]],
#  [[0.0], [0.01]],
#  [[0.02], [0.05]],
#  [[0.12], [0.31]],
#  [[0.22], [0.37]])

# %%
#this method takes the first word in a sentence and categorises it into one of five lists
#a lists with all those words is returned
def split_first_words(model_group, index_list):
    first_word = [model_group[i][0][3] for i in index_list]

    position = [i for i in first_word if i in position_words]
    color = [i for i in first_word if i in color_words]
    size = [i for i in first_word if i in size_words]
    rel_pos=[i for i in first_word if i in rel_pos_words]
    stopwords_english = stopwords.words("english")
    stop = [i for i in first_word if i in stopwords_english]

    rest = [i for i in first_word if i not in stopwords_english and i not in position_words and i not in color_words and i not in size_words and i not in rel_pos_words]
    
    return stop, position, color, size, rel_pos, rest, first_word

#calculates the first word and splits them by word category
def first_words(binary_grouped,model_group):
    
    stop_wrong,pos_wrong,rest_wrong,color_wrong,size_wrong,rel_pos_wrong=([] for i in range(6))
    stop_right,pos_right,rest_right,color_right,size_right,rel_pos_right=([] for i in range(6))

    #split each example into examples that guess correctly on the first word or not
    right_only = []
    wrong_only = []
    for index, entry in enumerate(binary_grouped):
        
        
        if entry[0]==1:
            right_only.append(index)
        elif entry[0]==0:
            wrong_only.append(index)
        else:
            print("something is very wrong")
        
    all_entries = [right_only, wrong_only]
    types = ["right", "wrong"]


    #loop through the right,wrong lists and make lists for each  word condition
    #and calculate the ratio
    for lst, typ in zip(all_entries, types):
        stop, position,color,size,rel_pos, rest, first_word = split_first_words(model_group, lst)
        stop_ratio, pos_ratio,color_ratio,size_ratio,rel_pos_ratio,rest_ratio = calculate_ratios(stop, position,color,size,rel_pos,rest, first_word)

        if typ == "wrong":
            stop_wrong.append(stop_ratio)
            pos_wrong.append(pos_ratio)
            color_wrong.append(color_ratio)
            size_wrong.append(size_ratio)
            rel_pos_wrong.append(rel_pos_ratio)
            rest_wrong.append(rest_ratio)
        
        elif typ == "right":
            stop_right.append(stop_ratio)
            pos_right.append(pos_ratio)
            color_right.append(color_ratio)
            size_right.append(size_ratio)
            rel_pos_right.append(rel_pos_ratio)
            rest_right.append(rest_ratio)
       
        else:
            print("Something went very wrong")

    pos_all=[pos_right,pos_wrong]
    color_all=[color_right,color_wrong]
    size_all=[size_right,size_wrong]
    rel_pos_all=[rel_pos_right,rel_pos_wrong]
    stop_all=[stop_right,stop_wrong]
    rest_all=[rest_right,rest_wrong]
    
    
    return pos_all,color_all,size_all,rel_pos_all,stop_all,rest_all

# %%
#split all words into word categories
def split_all_words(model_group, index_list):
   
    stopwords_english = stopwords.words()
    stop, position, rest, color, size, rel_pos = ([] for j in range(6))

    sent_list = []
    
    # Iterate over model_group to select sentences based on the provided index list
    for i in range(len(model_group)):
        if i in index_list:
            sent = model_group[i][-1][3].split()
            sent_list.append(sent)

    # Iterate over sentences and words to categorize the first word into specific lists
    for sent in sent_list:
        for word in sent:
            if word in position_words:
                position.append(word)
                
            elif word in color_words:
                color.append(word)
                
            elif word in size_words:
                size.append(word)
                
            elif word in rel_pos_words:
                rel_pos.append(word)
                
            elif word in stopwords_english:
                stop.append(word)
                
            else:
                rest.append(word)
    
    return stop, position, color, size, rel_pos, rest, sent_list

# Define a function named 'words' that calculates word category ratios for entries that are right, wrong, or mixed.
def words(binary_grouped, model_group):
    
    # Initialize lists to store ratios for different word categories
    stop_wrong, pos_wrong, rest_wrong, color_wrong, size_wrong, rel_pos_wrong = ([] for i in range(6))
    stop_right, pos_right, rest_right, color_right, size_right, rel_pos_right = ([] for i in range(6))
    stop_mixed, pos_mixed, rest_mixed, color_mixed, size_mixed, rel_pos_mixed = ([] for i in range(6))

    # Split up the list into entries where each guess is correct, wrong, or mixed
    right_only = []
    wrong_only = []
    mixed_only = []

    for index, entry in enumerate(binary_grouped):
        if all(p == 1 for p in entry):
            right_only.append(index)
        elif all(p == 0 for p in entry):
            wrong_only.append(index)
        else:
            mixed_only.append(index)

    all_entries = [right_only, wrong_only, mixed_only]
    types = ["right", "wrong", "mixed"]

    # Loop through the right, wrong, and mixed lists and make lists for each word condition
    for lst, typ in zip(all_entries, types):
        stop, position, color, size, rel_pos, rest, first_word = split_all_words(model_group, lst)
        stop_ratio, pos_ratio, color_ratio, size_ratio, rel_pos_ratio, rest_ratio = calculate_ratios(stop, position, color, size, rel_pos, rest, first_word)

        if typ == "wrong":
            stop_wrong.append(stop_ratio)
            pos_wrong.append(pos_ratio)
            color_wrong.append(color_ratio)
            size_wrong.append(size_ratio)
            rel_pos_wrong.append(rel_pos_ratio)
            rest_wrong.append(rest_ratio)
        elif typ == "right":
            stop_right.append(stop_ratio)
            pos_right.append(pos_ratio)
            color_right.append(color_ratio)
            size_right.append(size_ratio)
            rel_pos_right.append(rel_pos_ratio)
            rest_right.append(rest_ratio)
        elif typ == "mixed":
            stop_mixed.append(stop_ratio)
            pos_mixed.append(pos_ratio)
            color_mixed.append(color_ratio)
            size_mixed.append(size_ratio)
            rel_pos_mixed.append(rel_pos_ratio)
            rest_mixed.append(rest_ratio)
        else:
            print("Something went very wrong")

    pos_all = [pos_right, pos_wrong, pos_mixed]
    color_all = [color_right, color_wrong, color_mixed]
    size_all = [size_right, size_wrong, size_mixed]
    rel_pos_all = [rel_pos_right, rel_pos_wrong, rel_pos_mixed]
    stop_all = [stop_right, stop_wrong, stop_mixed]
    rest_all = [rest_right, rest_wrong, rest_mixed]

    return pos_all, color_all, size_all, rel_pos_all, stop_all, rest_all


words(binary_grouped, model_group)
# Out:
# ([[0.32], [0.23], [0.3]],
#  [[0.06], [0.06], [0.05]],
#  [[0.01], [0.0], [0.01]],
#  [[0.02], [0.04], [0.03]],
#  [[0.19], [0.27], [0.3]],
#  [[0.4], [0.4], [0.33]])

# %%
#make a dataframe out of the results for each word type
def make_wordtype_frame(type_list,typ,setting):

    data_typ={}

    dataset_index=["unc testB", "unc testA", "unc val","unc+ testB", "unc+ testA", "unc+ val", "gref_umd test", "gref_umd val", "gref val"]
    #dataset_index=["unc testB","unc testA","unc val"]
   

    data_typ[typ]=dataset_index
    data_typ["Right"]=type_list[0]
    data_typ["Wrong"]=type_list[1]

    if setting=="all":
        data_typ["Mixed"]=type_list[2]


    df_typ=pd.DataFrame(data_typ)

    df_typ[df_typ.select_dtypes(include=['number']).columns] *= 100

    df_typ.set_index(typ,inplace=True)
    
    
    #with open(r"/home/users/fschreiber/project/data_frames/all words/"+typ+"_tvg.p","wb") as f:
    #    pickle.dump(df_typ,f)
   

    
    df_typ=df_typ.style.format(precision=1).background_gradient(cmap="Blues",axis=1)
    
   
    return df_typ

# %%
setting="all"
mode="inc"
model_input="TVG"
split_list=["testB","testA","val","test"]
dataset_list=["unc","unc+","gref_umd","gref"]
#dataset_list=["unc"]

pos_all,color_all,size_all,rel_pos_all,stop_all,rest_all=([] for i in range(6))


#load the data
for file in dataset_list:
    for split in split_list:
    
        #if the data set does not exist ignore
        pred_bbox_list,target_bbox_list,inc_len,model,binary_grouped= load_data(model_input,mode,file,split)
        if pred_bbox_list==-1 or target_bbox_list==-1:
             
             pass
        
        else:
        
            print(file+split)

            model_group=group_by_increment(model,inc_len)

            if setting=="first":
                pos_hold,color_hold,size_hold,rel_pos_hold,stop_hold,rest_hold=first_words(binary_grouped,model_group)
            
            elif setting =="all":

                pos_hold,color_hold,size_hold,rel_pos_hold,stop_hold,rest_hold=words(binary_grouped,model_group)

            elif setting=="change":
                pos_hold,color_hold,size_hold,rel_pos_hold,stop_hold,rest_hold=change_words(binary_grouped,model_group)
            
            else:
                print("setting can be either first or all you choose:",setting)
                break

            pos_all.append(pos_hold)
            color_all.append(color_hold)
            size_all.append(size_hold)
            rel_pos_all.append(rel_pos_hold)
            stop_all.append(stop_hold)
            rest_all.append(rest_hold)



all_lists=[pos_all,color_all,size_all,rel_pos_all,stop_all,rest_all]
all_typ=["Position","Color","Size","Relative Position","Stopwords","Rest"]


#transform data into more readable format
for i in range(len(all_lists)):

    flattened_list = [item for sublist1 in all_lists[i] for sublist2 in sublist1 for item in sublist2]

    if setting=="first" or setting=="change":
        list1, list2 = flattened_list[::2], flattened_list[1::2]
        all_lists[i]=[list1,list2]

    elif setting=="all":
        list1, list2, list3 = flattened_list[::3], flattened_list[1::3], flattened_list[2::3]

        all_lists[i] = [list1, list2, list3]
    

#show dataframes
for i,j in zip(all_lists,all_typ):

    display(make_wordtype_frame(i,j,setting))
    #df=make_wordtype_frame(i,j,setting)

    #display(df)
# Out:
# unctestB
# unctestA
# uncval
# unc+testB
# unc+testA
# unc+val
# gref_umdval
# gref_umdtest
# grefval
# <style type="text/css">
# #T_3ebf7_row0_col0, #T_3ebf7_row1_col0, #T_3ebf7_row1_col2, #T_3ebf7_row2_col0, #T_3ebf7_row3_col0, #T_3ebf7_row4_col1, #T_3ebf7_row4_col2, #T_3ebf7_row6_col2, #T_3ebf7_row7_col2, #T_3ebf7_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3ebf7_row0_col1, #T_3ebf7_row1_col1, #T_3ebf7_row2_col1, #T_3ebf7_row3_col1, #T_3ebf7_row4_col0, #T_3ebf7_row5_col0, #T_3ebf7_row5_col1, #T_3ebf7_row5_col2, #T_3ebf7_row6_col0, #T_3ebf7_row6_col1, #T_3ebf7_row7_col0, #T_3ebf7_row7_col1, #T_3ebf7_row8_col0, #T_3ebf7_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3ebf7_row0_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_3ebf7_row2_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_3ebf7_row3_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# </style>
# <table id="T_3ebf7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ebf7_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_3ebf7_row0_col0" class="data row0 col0" >33.0</td>
#       <td id="T_3ebf7_row0_col1" class="data row0 col1" >22.0</td>
#       <td id="T_3ebf7_row0_col2" class="data row0 col2" >29.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_3ebf7_row1_col0" class="data row1 col0" >20.0</td>
#       <td id="T_3ebf7_row1_col1" class="data row1 col1" >13.0</td>
#       <td id="T_3ebf7_row1_col2" class="data row1 col2" >20.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_3ebf7_row2_col0" class="data row2 col0" >25.0</td>
#       <td id="T_3ebf7_row2_col1" class="data row2 col1" >18.0</td>
#       <td id="T_3ebf7_row2_col2" class="data row2 col2" >24.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_3ebf7_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_3ebf7_row3_col1" class="data row3 col1" >4.0</td>
#       <td id="T_3ebf7_row3_col2" class="data row3 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_3ebf7_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_3ebf7_row4_col1" class="data row4 col1" >3.0</td>
#       <td id="T_3ebf7_row4_col2" class="data row4 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_3ebf7_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_3ebf7_row5_col1" class="data row5 col1" >4.0</td>
#       <td id="T_3ebf7_row5_col2" class="data row5 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_3ebf7_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_3ebf7_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_3ebf7_row6_col2" class="data row6 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_3ebf7_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_3ebf7_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_3ebf7_row7_col2" class="data row7 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebf7_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_3ebf7_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_3ebf7_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_3ebf7_row8_col2" class="data row8 col2" >5.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1a2cb_row0_col0, #T_1a2cb_row0_col1, #T_1a2cb_row1_col1, #T_1a2cb_row2_col1, #T_1a2cb_row3_col0, #T_1a2cb_row4_col0, #T_1a2cb_row5_col0, #T_1a2cb_row6_col1, #T_1a2cb_row6_col2, #T_1a2cb_row7_col1, #T_1a2cb_row7_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1a2cb_row0_col2, #T_1a2cb_row1_col0, #T_1a2cb_row1_col2, #T_1a2cb_row2_col0, #T_1a2cb_row2_col2, #T_1a2cb_row3_col1, #T_1a2cb_row3_col2, #T_1a2cb_row4_col1, #T_1a2cb_row5_col1, #T_1a2cb_row6_col0, #T_1a2cb_row7_col0, #T_1a2cb_row8_col0, #T_1a2cb_row8_col1, #T_1a2cb_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1a2cb_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_1a2cb_row5_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_1a2cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a2cb_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_1a2cb_row0_col0" class="data row0 col0" >6.0</td>
#       <td id="T_1a2cb_row0_col1" class="data row0 col1" >6.0</td>
#       <td id="T_1a2cb_row0_col2" class="data row0 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_1a2cb_row1_col0" class="data row1 col0" >8.0</td>
#       <td id="T_1a2cb_row1_col1" class="data row1 col1" >9.0</td>
#       <td id="T_1a2cb_row1_col2" class="data row1 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_1a2cb_row2_col0" class="data row2 col0" >7.0</td>
#       <td id="T_1a2cb_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_1a2cb_row2_col2" class="data row2 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_1a2cb_row3_col0" class="data row3 col0" >11.0</td>
#       <td id="T_1a2cb_row3_col1" class="data row3 col1" >8.0</td>
#       <td id="T_1a2cb_row3_col2" class="data row3 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_1a2cb_row4_col0" class="data row4 col0" >16.0</td>
#       <td id="T_1a2cb_row4_col1" class="data row4 col1" >10.0</td>
#       <td id="T_1a2cb_row4_col2" class="data row4 col2" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_1a2cb_row5_col0" class="data row5 col0" >15.0</td>
#       <td id="T_1a2cb_row5_col1" class="data row5 col1" >9.0</td>
#       <td id="T_1a2cb_row5_col2" class="data row5 col2" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_1a2cb_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_1a2cb_row6_col1" class="data row6 col1" >7.0</td>
#       <td id="T_1a2cb_row6_col2" class="data row6 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_1a2cb_row7_col0" class="data row7 col0" >6.0</td>
#       <td id="T_1a2cb_row7_col1" class="data row7 col1" >7.0</td>
#       <td id="T_1a2cb_row7_col2" class="data row7 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_1a2cb_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_1a2cb_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_1a2cb_row8_col1" class="data row8 col1" >7.0</td>
#       <td id="T_1a2cb_row8_col2" class="data row8 col2" >7.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_921dd_row0_col0, #T_921dd_row0_col1, #T_921dd_row0_col2, #T_921dd_row1_col1, #T_921dd_row1_col2, #T_921dd_row2_col2, #T_921dd_row3_col1, #T_921dd_row3_col2, #T_921dd_row4_col0, #T_921dd_row4_col1, #T_921dd_row4_col2, #T_921dd_row5_col1, #T_921dd_row5_col2, #T_921dd_row6_col0, #T_921dd_row6_col1, #T_921dd_row6_col2, #T_921dd_row7_col0, #T_921dd_row7_col1, #T_921dd_row7_col2, #T_921dd_row8_col0, #T_921dd_row8_col1, #T_921dd_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_921dd_row1_col0, #T_921dd_row2_col0, #T_921dd_row2_col1, #T_921dd_row3_col0, #T_921dd_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_921dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_921dd_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_921dd_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_921dd_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_921dd_row0_col2" class="data row0 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_921dd_row1_col0" class="data row1 col0" >1.0</td>
#       <td id="T_921dd_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_921dd_row1_col2" class="data row1 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_921dd_row2_col0" class="data row2 col0" >1.0</td>
#       <td id="T_921dd_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_921dd_row2_col2" class="data row2 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_921dd_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_921dd_row3_col1" class="data row3 col1" >1.0</td>
#       <td id="T_921dd_row3_col2" class="data row3 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_921dd_row4_col0" class="data row4 col0" >1.0</td>
#       <td id="T_921dd_row4_col1" class="data row4 col1" >1.0</td>
#       <td id="T_921dd_row4_col2" class="data row4 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_921dd_row5_col0" class="data row5 col0" >3.0</td>
#       <td id="T_921dd_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_921dd_row5_col2" class="data row5 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_921dd_row6_col0" class="data row6 col0" >1.0</td>
#       <td id="T_921dd_row6_col1" class="data row6 col1" >1.0</td>
#       <td id="T_921dd_row6_col2" class="data row6 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_921dd_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_921dd_row7_col1" class="data row7 col1" >1.0</td>
#       <td id="T_921dd_row7_col2" class="data row7 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_921dd_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_921dd_row8_col0" class="data row8 col0" >1.0</td>
#       <td id="T_921dd_row8_col1" class="data row8 col1" >1.0</td>
#       <td id="T_921dd_row8_col2" class="data row8 col2" >1.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_65965_row0_col0, #T_65965_row1_col0, #T_65965_row2_col0, #T_65965_row3_col0, #T_65965_row4_col0, #T_65965_row5_col0, #T_65965_row6_col0, #T_65965_row6_col1, #T_65965_row6_col2, #T_65965_row7_col0, #T_65965_row7_col1, #T_65965_row7_col2, #T_65965_row8_col0, #T_65965_row8_col1, #T_65965_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_65965_row0_col1, #T_65965_row1_col1, #T_65965_row2_col1, #T_65965_row3_col1, #T_65965_row3_col2, #T_65965_row4_col1, #T_65965_row5_col1, #T_65965_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_65965_row0_col2, #T_65965_row1_col2, #T_65965_row2_col2, #T_65965_row4_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_65965_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Relative Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65965_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_65965_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_65965_row0_col1" class="data row0 col1" >4.0</td>
#       <td id="T_65965_row0_col2" class="data row0 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_65965_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_65965_row1_col1" class="data row1 col1" >4.0</td>
#       <td id="T_65965_row1_col2" class="data row1 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_65965_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_65965_row2_col1" class="data row2 col1" >4.0</td>
#       <td id="T_65965_row2_col2" class="data row2 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_65965_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_65965_row3_col1" class="data row3 col1" >6.0</td>
#       <td id="T_65965_row3_col2" class="data row3 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_65965_row4_col0" class="data row4 col0" >4.0</td>
#       <td id="T_65965_row4_col1" class="data row4 col1" >6.0</td>
#       <td id="T_65965_row4_col2" class="data row4 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_65965_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_65965_row5_col1" class="data row5 col1" >6.0</td>
#       <td id="T_65965_row5_col2" class="data row5 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_65965_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_65965_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_65965_row6_col2" class="data row6 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_65965_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_65965_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_65965_row7_col2" class="data row7 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_65965_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_65965_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_65965_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_65965_row8_col2" class="data row8 col2" >4.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ce96e_row0_col0, #T_ce96e_row1_col0, #T_ce96e_row2_col0, #T_ce96e_row3_col0, #T_ce96e_row4_col0, #T_ce96e_row5_col0, #T_ce96e_row6_col0, #T_ce96e_row7_col0, #T_ce96e_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ce96e_row0_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_ce96e_row0_col2, #T_ce96e_row1_col2, #T_ce96e_row2_col2, #T_ce96e_row3_col2, #T_ce96e_row4_col2, #T_ce96e_row5_col2, #T_ce96e_row6_col2, #T_ce96e_row7_col2, #T_ce96e_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ce96e_row1_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_ce96e_row2_col1, #T_ce96e_row8_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_ce96e_row3_col1, #T_ce96e_row5_col1, #T_ce96e_row6_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_ce96e_row4_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ce96e_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce96e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Stopwords</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce96e_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_ce96e_row0_col0" class="data row0 col0" >18.0</td>
#       <td id="T_ce96e_row0_col1" class="data row0 col1" >27.0</td>
#       <td id="T_ce96e_row0_col2" class="data row0 col2" >29.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_ce96e_row1_col0" class="data row1 col0" >23.0</td>
#       <td id="T_ce96e_row1_col1" class="data row1 col1" >26.0</td>
#       <td id="T_ce96e_row1_col2" class="data row1 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_ce96e_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_ce96e_row2_col1" class="data row2 col1" >27.0</td>
#       <td id="T_ce96e_row2_col2" class="data row2 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_ce96e_row3_col0" class="data row3 col0" >21.0</td>
#       <td id="T_ce96e_row3_col1" class="data row3 col1" >26.0</td>
#       <td id="T_ce96e_row3_col2" class="data row3 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_ce96e_row4_col0" class="data row4 col0" >22.0</td>
#       <td id="T_ce96e_row4_col1" class="data row4 col1" >24.0</td>
#       <td id="T_ce96e_row4_col2" class="data row4 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_ce96e_row5_col0" class="data row5 col0" >21.0</td>
#       <td id="T_ce96e_row5_col1" class="data row5 col1" >26.0</td>
#       <td id="T_ce96e_row5_col2" class="data row5 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_ce96e_row6_col0" class="data row6 col0" >43.0</td>
#       <td id="T_ce96e_row6_col1" class="data row6 col1" >44.0</td>
#       <td id="T_ce96e_row6_col2" class="data row6 col2" >45.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_ce96e_row7_col0" class="data row7 col0" >42.0</td>
#       <td id="T_ce96e_row7_col1" class="data row7 col1" >44.0</td>
#       <td id="T_ce96e_row7_col2" class="data row7 col2" >45.0</td>
#     </tr>
#     <tr>
#       <th id="T_ce96e_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_ce96e_row8_col0" class="data row8 col0" >41.0</td>
#       <td id="T_ce96e_row8_col1" class="data row8 col1" >44.0</td>
#       <td id="T_ce96e_row8_col2" class="data row8 col2" >46.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e3a21_row0_col0, #T_e3a21_row0_col1, #T_e3a21_row1_col1, #T_e3a21_row2_col0, #T_e3a21_row3_col1, #T_e3a21_row4_col0, #T_e3a21_row4_col1, #T_e3a21_row5_col0, #T_e3a21_row5_col1, #T_e3a21_row6_col0, #T_e3a21_row7_col0, #T_e3a21_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e3a21_row0_col2, #T_e3a21_row1_col2, #T_e3a21_row2_col2, #T_e3a21_row3_col2, #T_e3a21_row4_col2, #T_e3a21_row5_col2, #T_e3a21_row6_col2, #T_e3a21_row7_col2, #T_e3a21_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e3a21_row1_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_e3a21_row2_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_e3a21_row3_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_e3a21_row6_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_e3a21_row7_col1, #T_e3a21_row8_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# </style>
# <table id="T_e3a21_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rest</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a21_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_e3a21_row0_col0" class="data row0 col0" >40.0</td>
#       <td id="T_e3a21_row0_col1" class="data row0 col1" >40.0</td>
#       <td id="T_e3a21_row0_col2" class="data row0 col2" >33.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_e3a21_row1_col0" class="data row1 col0" >45.0</td>
#       <td id="T_e3a21_row1_col1" class="data row1 col1" >47.0</td>
#       <td id="T_e3a21_row1_col2" class="data row1 col2" >36.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_e3a21_row2_col0" class="data row2 col0" >43.0</td>
#       <td id="T_e3a21_row2_col1" class="data row2 col1" >42.0</td>
#       <td id="T_e3a21_row2_col2" class="data row2 col2" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_e3a21_row3_col0" class="data row3 col0" >53.0</td>
#       <td id="T_e3a21_row3_col1" class="data row3 col1" >54.0</td>
#       <td id="T_e3a21_row3_col2" class="data row3 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_e3a21_row4_col0" class="data row4 col0" >55.0</td>
#       <td id="T_e3a21_row4_col1" class="data row4 col1" >55.0</td>
#       <td id="T_e3a21_row4_col2" class="data row4 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_e3a21_row5_col0" class="data row5 col0" >54.0</td>
#       <td id="T_e3a21_row5_col1" class="data row5 col1" >54.0</td>
#       <td id="T_e3a21_row5_col2" class="data row5 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_e3a21_row6_col0" class="data row6 col0" >42.0</td>
#       <td id="T_e3a21_row6_col1" class="data row6 col1" >40.0</td>
#       <td id="T_e3a21_row6_col2" class="data row6 col2" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_e3a21_row7_col0" class="data row7 col0" >43.0</td>
#       <td id="T_e3a21_row7_col1" class="data row7 col1" >40.0</td>
#       <td id="T_e3a21_row7_col2" class="data row7 col2" >39.0</td>
#     </tr>
#     <tr>
#       <th id="T_e3a21_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_e3a21_row8_col0" class="data row8 col0" >43.0</td>
#       <td id="T_e3a21_row8_col1" class="data row8 col1" >40.0</td>
#       <td id="T_e3a21_row8_col2" class="data row8 col2" >39.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
import dataframe_image as dfi

# %%
with open(r"/home/users/fschreiber/project/data_frames/first words/Color_resc.p","rb") as f:
    color_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Color_tvg.p","rb") as f:
    color_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Position_resc.p","rb") as f:
    pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Position_tvg.p","rb") as f:
    pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Relative Position_resc.p","rb") as f:
    rel_pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Relative Position_tvg.p","rb") as f:
    rel_pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Size_resc.p","rb") as f:
    size_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Size_tvg.p","rb") as f:
    size_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Stopwords_resc.p","rb") as f:
    stopwords_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Stopwords_tvg.p","rb") as f:
    stopwords_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Rest_resc.p","rb") as f:
    rest_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/first words/Rest_tvg.p","rb") as f:
    rest_tvg_df=pickle.load(f)


resc_all_first=[pos_resc_df,rel_pos_resc_df,color_resc_df,size_resc_df,stopwords_resc_df,rest_resc_df]
tvg_all_first=[pos_tvg_df,rel_pos_tvg_df,color_tvg_df,size_tvg_df,stopwords_tvg_df,rest_tvg_df]

# %%
with open(r"/home/users/fschreiber/project/data_frames/all words/Color_resc.p","rb") as f:
    color_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Color_tvg.p","rb") as f:
    color_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Position_resc.p","rb") as f:
    pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Position_tvg.p","rb") as f:
    pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Relative Position_resc.p","rb") as f:
    rel_pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Relative Position_tvg.p","rb") as f:
    rel_pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Size_resc.p","rb") as f:
    size_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Size_tvg.p","rb") as f:
    size_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Stopwords_resc.p","rb") as f:
    stopwords_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Stopwords_tvg.p","rb") as f:
    stopwords_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Rest_resc.p","rb") as f:
    rest_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/all words/Rest_tvg.p","rb") as f:
    rest_tvg_df=pickle.load(f)


resc_all_all=[pos_resc_df,rel_pos_resc_df,color_resc_df,size_resc_df,stopwords_resc_df,rest_resc_df]
tvg_all_all=[pos_tvg_df,rel_pos_tvg_df,color_tvg_df,size_tvg_df,stopwords_tvg_df,rest_tvg_df]

# %%
with open(r"/home/users/fschreiber/project/data_frames/change words/Color_resc.p","rb") as f:
    color_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Color_tvg.p","rb") as f:
    color_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Position_resc.p","rb") as f:
    pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Position_tvg.p","rb") as f:
    pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Relative Position_resc.p","rb") as f:
    rel_pos_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Relative Position_tvg.p","rb") as f:
    rel_pos_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Size_resc.p","rb") as f:
    size_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Size_tvg.p","rb") as f:
    size_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Stopwords_resc.p","rb") as f:
    stopwords_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Stopwords_tvg.p","rb") as f:
    stopwords_tvg_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Rest_resc.p","rb") as f:
    rest_resc_df=pickle.load(f)

with open(r"/home/users/fschreiber/project/data_frames/change words/Rest_tvg.p","rb") as f:
    rest_tvg_df=pickle.load(f)


resc_all_change=[pos_resc_df,rel_pos_resc_df,color_resc_df,size_resc_df,stopwords_resc_df,rest_resc_df]
tvg_all_change=[pos_tvg_df,rel_pos_tvg_df,color_tvg_df,size_tvg_df,stopwords_tvg_df,rest_tvg_df]

# %%
for resc,tvg in zip(resc_all_all,tvg_all_all):
    print("All")
    #display((resc+tvg)/2)
    print(((resc+tvg)/2).to_latex())
    print()




for resc,tvg in zip(resc_all_first,tvg_all_first):
    print("First")
    #display((resc+tvg)/2)
    print(((resc+tvg)/2).to_latex())
    print()


for resc,tvg in zip(resc_all_change,tvg_all_change):
    print("Change")
    #display((resc+tvg)/2)
    print(((resc+tvg)/2).to_latex())
    print()
# Out:
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Position      &        &        &        \\
# \midrule
# unc testB     &   32.5 &   22.5 &   29.5 \\
# unc testA     &   20.0 &   13.0 &   20.5 \\
# unc val       &   25.0 &   18.5 &   24.5 \\
# unc+ testB    &    6.5 &    4.5 &    5.0 \\
# unc+ testA    &    2.0 &    3.0 &    3.0 \\
# unc+ val      &    4.0 &    4.0 &    4.0 \\
# gref\_umd test &    4.0 &    4.0 &    5.0 \\
# gref\_umd val  &    4.0 &    4.0 &    5.0 \\
# gref val      &    4.0 &    4.0 &    5.0 \\
# \bottomrule
# \end{tabular}
#
#
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Relative Position &        &        &        \\
# \midrule
# unc testB         &    2.0 &    4.0 &    3.0 \\
# unc testA         &    2.0 &    4.0 &    3.0 \\
# unc val           &    2.0 &    4.0 &    3.0 \\
# unc+ testB        &    4.0 &    6.0 &    6.0 \\
# unc+ testA        &    4.0 &    6.0 &    5.5 \\
# unc+ val          &    4.0 &    6.0 &    6.0 \\
# gref\_umd test     &    4.0 &    4.0 &    4.0 \\
# gref\_umd val      &    4.0 &    4.0 &    4.0 \\
# gref val          &    4.0 &    4.0 &    4.0 \\
# \bottomrule
# \end{tabular}
#
#
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Color         &        &        &        \\
# \midrule
# unc testB     &    6.0 &    6.0 &    5.0 \\
# unc testA     &    8.0 &    9.0 &    8.0 \\
# unc val       &    7.5 &    8.0 &    6.5 \\
# unc+ testB    &   11.0 &    8.5 &    7.5 \\
# unc+ testA    &   15.5 &   11.0 &   12.5 \\
# unc+ val      &   14.5 &    9.0 &   10.0 \\
# gref\_umd test &    6.0 &    7.0 &    6.5 \\
# gref\_umd val  &    6.5 &    7.0 &    7.0 \\
# gref val      &    7.0 &    7.0 &    7.0 \\
# \bottomrule
# \end{tabular}
#
#
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Size          &        &        &        \\
# \midrule
# unc testB     &    1.0 &    0.5 &    1.0 \\
# unc testA     &    1.0 &    0.0 &    0.0 \\
# unc val       &    1.0 &    1.0 &    0.0 \\
# unc+ testB    &    3.5 &    1.5 &    1.0 \\
# unc+ testA    &    1.0 &    1.0 &    1.0 \\
# unc+ val      &    2.5 &    1.0 &    1.0 \\
# gref\_umd test &    1.0 &    1.0 &    1.0 \\
# gref\_umd val  &    1.0 &    1.0 &    1.0 \\
# gref val      &    1.0 &    1.0 &    1.0 \\
# \bottomrule
# \end{tabular}
#
#
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Stopwords     &        &        &        \\
# \midrule
# unc testB     &   18.5 &   27.0 &   29.5 \\
# unc testA     &   23.5 &   26.5 &   32.0 \\
# unc val       &   21.0 &   27.5 &   31.0 \\
# unc+ testB    &   21.5 &   26.5 &   31.5 \\
# unc+ testA    &   22.5 &   24.5 &   30.5 \\
# unc+ val      &   21.0 &   26.5 &   31.0 \\
# gref\_umd test &   43.0 &   43.5 &   45.5 \\
# gref\_umd val  &   42.5 &   43.5 &   45.0 \\
# gref val      &   41.5 &   44.0 &   46.0 \\
# \bottomrule
# \end{tabular}
#
#
# All
# \begin{tabular}{lrrr}
# \toprule
# {} &  Right &  Wrong &  Mixed \\
# Rest          &        &        &        \\
# \midrule
# unc testB     &   40.0 &   40.0 &   33.0 \\
# unc testA     &   45.0 &   46.5 &   36.0 \\
# unc val       &   43.0 &   42.0 &   35.0 \\
# unc+ testB    &   53.0 &   53.0 &   48.5 \\
# unc+ testA    &   55.0 &   54.5 &   48.0 \\
# unc+ val      &   54.0 &   53.5 &   48.0 \\
# gref\_umd test &   42.0 &   40.0 &   38.0 \\
# gref\_umd val  &   42.5 &   40.0 &   38.5 \\
# gref val      &   42.5 &   40.0 &   39.0 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Position      &        &        \\
# \midrule
# unc testB     &   49.0 &   23.0 \\
# unc testA     &   22.5 &    9.5 \\
# unc val       &   33.0 &   16.5 \\
# unc+ testB    &    7.5 &    3.5 \\
# unc+ testA    &    1.5 &    2.0 \\
# unc+ val      &    4.0 &    3.0 \\
# gref\_umd test &    1.0 &    1.0 \\
# gref\_umd val  &    1.0 &    1.0 \\
# gref val      &    1.0 &    1.0 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Relative Position &        &        \\
# \midrule
# unc testB         &    0.0 &    1.0 \\
# unc testA         &    0.0 &    0.0 \\
# unc val           &    0.0 &    0.0 \\
# unc+ testB        &    0.5 &    0.5 \\
# unc+ testA        &    0.0 &    0.0 \\
# unc+ val          &    0.0 &    0.0 \\
# gref\_umd test     &    0.0 &    0.0 \\
# gref\_umd val      &    0.0 &    0.0 \\
# gref val          &    0.0 &    0.0 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Color         &        &        \\
# \midrule
# unc testB     &   10.0 &   12.5 \\
# unc testA     &    9.0 &    9.0 \\
# unc val       &   11.0 &   10.0 \\
# unc+ testB    &   21.0 &   15.0 \\
# unc+ testA    &   22.5 &   14.0 \\
# unc+ val      &   23.0 &   14.0 \\
# gref\_umd test &    3.5 &    4.0 \\
# gref\_umd val  &    4.0 &    4.0 \\
# gref val      &    4.0 &    4.0 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Size          &        &        \\
# \midrule
# unc testB     &    2.5 &    1.0 \\
# unc testA     &    1.0 &    1.0 \\
# unc val       &    2.0 &    1.0 \\
# unc+ testB    &    8.0 &    3.5 \\
# unc+ testA    &    2.0 &    2.0 \\
# unc+ val      &    5.5 &    3.0 \\
# gref\_umd test &    1.0 &    1.0 \\
# gref\_umd val  &    2.0 &    1.0 \\
# gref val      &    1.5 &    1.0 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Stopwords     &        &        \\
# \midrule
# unc testB     &    4.0 &    7.5 \\
# unc testA     &    3.0 &    6.5 \\
# unc val       &    3.0 &    7.0 \\
# unc+ testB    &    5.0 &    9.0 \\
# unc+ testA    &    3.5 &    7.5 \\
# unc+ val      &    4.0 &    8.0 \\
# gref\_umd test &   69.5 &   78.0 \\
# gref\_umd val  &   69.5 &   78.5 \\
# gref val      &   64.5 &   79.5 \\
# \bottomrule
# \end{tabular}
#
#
# First
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Rest          &        &        \\
# \midrule
# unc testB     &   34.5 &   55.5 \\
# unc testA     &   64.0 &   74.0 \\
# unc val       &   51.0 &   65.5 \\
# unc+ testB    &   58.0 &   69.0 \\
# unc+ testA    &   70.0 &   75.0 \\
# unc+ val      &   64.0 &   72.5 \\
# gref\_umd test &   24.5 &   16.0 \\
# gref\_umd val  &   24.5 &   15.5 \\
# gref val      &   28.5 &   15.5 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Position      &        &        \\
# \midrule
# unc testB     &   60.0 &   25.0 \\
# unc testA     &   48.0 &   17.0 \\
# unc val       &   52.5 &   20.5 \\
# unc+ testB    &    9.0 &    7.5 \\
# unc+ testA    &    5.5 &    3.0 \\
# unc+ val      &    8.0 &    6.0 \\
# gref\_umd test &   11.0 &    6.5 \\
# gref\_umd val  &   11.5 &    6.5 \\
# gref val      &   11.5 &    5.5 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Relative Position &        &        \\
# \midrule
# unc testB         &    2.0 &    5.0 \\
# unc testA         &    2.0 &    3.5 \\
# unc val           &    2.0 &    4.5 \\
# unc+ testB        &    6.5 &    8.0 \\
# unc+ testA        &    4.0 &    8.0 \\
# unc+ val          &    5.0 &    7.5 \\
# gref\_umd test     &    2.5 &    3.5 \\
# gref\_umd val      &    2.5 &    3.5 \\
# gref val          &    2.0 &    3.5 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Color         &        &        \\
# \midrule
# unc testB     &    2.0 &    3.5 \\
# unc testA     &   10.5 &   10.5 \\
# unc val       &    8.0 &    7.0 \\
# unc+ testB    &    7.0 &    6.5 \\
# unc+ testA    &   22.5 &   14.5 \\
# unc+ val      &   16.5 &   10.5 \\
# gref\_umd test &    6.5 &    9.0 \\
# gref\_umd val  &    7.5 &    9.0 \\
# gref val      &    6.5 &    9.5 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Size          &        &        \\
# \midrule
# unc testB     &    0.0 &    1.0 \\
# unc testA     &    0.0 &    0.0 \\
# unc val       &    0.0 &    0.0 \\
# unc+ testB    &    1.0 &    0.0 \\
# unc+ testA    &    0.0 &    0.5 \\
# unc+ val      &    1.0 &    1.0 \\
# gref\_umd test &    2.0 &    1.0 \\
# gref\_umd val  &    2.0 &    1.0 \\
# gref val      &    2.0 &    1.0 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Stopwords     &        &        \\
# \midrule
# unc testB     &   12.5 &   32.5 \\
# unc testA     &   12.5 &   33.5 \\
# unc val       &   13.5 &   34.0 \\
# unc+ testB    &   25.0 &   29.0 \\
# unc+ testA    &   18.0 &   29.0 \\
# unc+ val      &   20.0 &   29.5 \\
# gref\_umd test &   18.0 &   27.0 \\
# gref\_umd val  &   17.5 &   28.5 \\
# gref val      &   14.5 &   25.0 \\
# \bottomrule
# \end{tabular}
#
#
# Change
# \begin{tabular}{lrr}
# \toprule
# {} &  Right &  Wrong \\
# Rest          &        &        \\
# \midrule
# unc testB     &   25.5 &   38.5 \\
# unc testA     &   29.5 &   39.0 \\
# unc val       &   26.5 &   39.5 \\
# unc+ testB    &   58.5 &   57.0 \\
# unc+ testA    &   54.5 &   53.0 \\
# unc+ val      &   54.5 &   53.5 \\
# gref\_umd test &   62.5 &   56.5 \\
# gref\_umd val  &   62.0 &   55.5 \\
# gref val      &   65.5 &   59.0 \\
# \bottomrule
# \end{tabular}

# %%
typ="Size"
types=["Position","Color","Size","Stopwords","Rest"]

everything=[resc_all_first,tvg_all_first,resc_all_all,tvg_all_all,resc_all_change,tvg_all_change]

for i in range(len(types)):

    if types[i]==typ:
        
        for j in everything:

            print(j[i].mean())
            
            display(j[i].style.format(precision=1).background_gradient(cmap="Blues",axis=1))
# Out:
# Right    12.111111
# Wrong     9.666667
# dtype: float64
# <style type="text/css">
# #T_3ebb2_row0_col0, #T_3ebb2_row1_col0, #T_3ebb2_row1_col1, #T_3ebb2_row2_col1, #T_3ebb2_row3_col1, #T_3ebb2_row4_col1, #T_3ebb2_row5_col1, #T_3ebb2_row6_col0, #T_3ebb2_row6_col1, #T_3ebb2_row7_col0, #T_3ebb2_row7_col1, #T_3ebb2_row8_col0, #T_3ebb2_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3ebb2_row0_col1, #T_3ebb2_row2_col0, #T_3ebb2_row3_col0, #T_3ebb2_row4_col0, #T_3ebb2_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3ebb2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ebb2_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_3ebb2_row0_col0" class="data row0 col0" >11.0</td>
#       <td id="T_3ebb2_row0_col1" class="data row0 col1" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_3ebb2_row1_col0" class="data row1 col0" >9.0</td>
#       <td id="T_3ebb2_row1_col1" class="data row1 col1" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_3ebb2_row2_col0" class="data row2 col0" >11.0</td>
#       <td id="T_3ebb2_row2_col1" class="data row2 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_3ebb2_row3_col0" class="data row3 col0" >21.0</td>
#       <td id="T_3ebb2_row3_col1" class="data row3 col1" >15.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_3ebb2_row4_col0" class="data row4 col0" >22.0</td>
#       <td id="T_3ebb2_row4_col1" class="data row4 col1" >15.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_3ebb2_row5_col0" class="data row5 col0" >23.0</td>
#       <td id="T_3ebb2_row5_col1" class="data row5 col1" >14.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_3ebb2_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_3ebb2_row6_col1" class="data row6 col1" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_3ebb2_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_3ebb2_row7_col1" class="data row7 col1" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_3ebb2_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_3ebb2_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_3ebb2_row8_col1" class="data row8 col1" >4.0</td>
#     </tr>
#   </tbody>
# </table>
# Right    11.888889
# Wrong     9.555556
# dtype: float64
# <style type="text/css">
# #T_524e4_row0_col0, #T_524e4_row1_col0, #T_524e4_row1_col1, #T_524e4_row2_col1, #T_524e4_row3_col1, #T_524e4_row4_col1, #T_524e4_row5_col1, #T_524e4_row6_col0, #T_524e4_row7_col0, #T_524e4_row7_col1, #T_524e4_row8_col0, #T_524e4_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_524e4_row0_col1, #T_524e4_row2_col0, #T_524e4_row3_col0, #T_524e4_row4_col0, #T_524e4_row5_col0, #T_524e4_row6_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_524e4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_524e4_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_524e4_row0_col0" class="data row0 col0" >9.0</td>
#       <td id="T_524e4_row0_col1" class="data row0 col1" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_524e4_row1_col0" class="data row1 col0" >9.0</td>
#       <td id="T_524e4_row1_col1" class="data row1 col1" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_524e4_row2_col0" class="data row2 col0" >11.0</td>
#       <td id="T_524e4_row2_col1" class="data row2 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_524e4_row3_col0" class="data row3 col0" >21.0</td>
#       <td id="T_524e4_row3_col1" class="data row3 col1" >15.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_524e4_row4_col0" class="data row4 col0" >23.0</td>
#       <td id="T_524e4_row4_col1" class="data row4 col1" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_524e4_row5_col0" class="data row5 col0" >23.0</td>
#       <td id="T_524e4_row5_col1" class="data row5 col1" >14.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_524e4_row6_col0" class="data row6 col0" >3.0</td>
#       <td id="T_524e4_row6_col1" class="data row6 col1" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_524e4_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_524e4_row7_col1" class="data row7 col1" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_524e4_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_524e4_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_524e4_row8_col1" class="data row8 col1" >4.0</td>
#     </tr>
#   </tbody>
# </table>
# Right    9.111111
# Wrong    8.222222
# Mixed    7.666667
# dtype: float64
# <style type="text/css">
# #T_846de_row0_col0, #T_846de_row0_col1, #T_846de_row1_col1, #T_846de_row2_col0, #T_846de_row2_col1, #T_846de_row3_col0, #T_846de_row4_col0, #T_846de_row5_col0, #T_846de_row6_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_846de_row0_col2, #T_846de_row1_col0, #T_846de_row1_col2, #T_846de_row2_col2, #T_846de_row3_col2, #T_846de_row4_col1, #T_846de_row5_col1, #T_846de_row6_col0, #T_846de_row6_col2, #T_846de_row7_col0, #T_846de_row7_col1, #T_846de_row7_col2, #T_846de_row8_col0, #T_846de_row8_col1, #T_846de_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_846de_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_846de_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_846de_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# </style>
# <table id="T_846de_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_846de_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_846de_row0_col0" class="data row0 col0" >6.0</td>
#       <td id="T_846de_row0_col1" class="data row0 col1" >6.0</td>
#       <td id="T_846de_row0_col2" class="data row0 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_846de_row1_col0" class="data row1 col0" >8.0</td>
#       <td id="T_846de_row1_col1" class="data row1 col1" >9.0</td>
#       <td id="T_846de_row1_col2" class="data row1 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_846de_row2_col0" class="data row2 col0" >8.0</td>
#       <td id="T_846de_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_846de_row2_col2" class="data row2 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_846de_row3_col0" class="data row3 col0" >11.0</td>
#       <td id="T_846de_row3_col1" class="data row3 col1" >9.0</td>
#       <td id="T_846de_row3_col2" class="data row3 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_846de_row4_col0" class="data row4 col0" >15.0</td>
#       <td id="T_846de_row4_col1" class="data row4 col1" >12.0</td>
#       <td id="T_846de_row4_col2" class="data row4 col2" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_846de_row5_col0" class="data row5 col0" >14.0</td>
#       <td id="T_846de_row5_col1" class="data row5 col1" >9.0</td>
#       <td id="T_846de_row5_col2" class="data row5 col2" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_846de_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_846de_row6_col1" class="data row6 col1" >7.0</td>
#       <td id="T_846de_row6_col2" class="data row6 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_846de_row7_col0" class="data row7 col0" >7.0</td>
#       <td id="T_846de_row7_col1" class="data row7 col1" >7.0</td>
#       <td id="T_846de_row7_col2" class="data row7 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_846de_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_846de_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_846de_row8_col1" class="data row8 col1" >7.0</td>
#       <td id="T_846de_row8_col2" class="data row8 col2" >7.0</td>
#     </tr>
#   </tbody>
# </table>
# Right    9.111111
# Wrong    7.888889
# Mixed    7.888889
# dtype: float64
# <style type="text/css">
# #T_c1633_row0_col0, #T_c1633_row0_col1, #T_c1633_row1_col1, #T_c1633_row2_col1, #T_c1633_row3_col0, #T_c1633_row4_col0, #T_c1633_row5_col0, #T_c1633_row6_col1, #T_c1633_row6_col2, #T_c1633_row7_col1, #T_c1633_row7_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c1633_row0_col2, #T_c1633_row1_col0, #T_c1633_row1_col2, #T_c1633_row2_col0, #T_c1633_row2_col2, #T_c1633_row3_col1, #T_c1633_row3_col2, #T_c1633_row4_col1, #T_c1633_row5_col1, #T_c1633_row6_col0, #T_c1633_row7_col0, #T_c1633_row8_col0, #T_c1633_row8_col1, #T_c1633_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c1633_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c1633_row5_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_c1633_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1633_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_c1633_row0_col0" class="data row0 col0" >6.0</td>
#       <td id="T_c1633_row0_col1" class="data row0 col1" >6.0</td>
#       <td id="T_c1633_row0_col2" class="data row0 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_c1633_row1_col0" class="data row1 col0" >8.0</td>
#       <td id="T_c1633_row1_col1" class="data row1 col1" >9.0</td>
#       <td id="T_c1633_row1_col2" class="data row1 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_c1633_row2_col0" class="data row2 col0" >7.0</td>
#       <td id="T_c1633_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_c1633_row2_col2" class="data row2 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_c1633_row3_col0" class="data row3 col0" >11.0</td>
#       <td id="T_c1633_row3_col1" class="data row3 col1" >8.0</td>
#       <td id="T_c1633_row3_col2" class="data row3 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_c1633_row4_col0" class="data row4 col0" >16.0</td>
#       <td id="T_c1633_row4_col1" class="data row4 col1" >10.0</td>
#       <td id="T_c1633_row4_col2" class="data row4 col2" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_c1633_row5_col0" class="data row5 col0" >15.0</td>
#       <td id="T_c1633_row5_col1" class="data row5 col1" >9.0</td>
#       <td id="T_c1633_row5_col2" class="data row5 col2" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_c1633_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_c1633_row6_col1" class="data row6 col1" >7.0</td>
#       <td id="T_c1633_row6_col2" class="data row6 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_c1633_row7_col0" class="data row7 col0" >6.0</td>
#       <td id="T_c1633_row7_col1" class="data row7 col1" >7.0</td>
#       <td id="T_c1633_row7_col2" class="data row7 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_c1633_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_c1633_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_c1633_row8_col1" class="data row8 col1" >7.0</td>
#       <td id="T_c1633_row8_col2" class="data row8 col2" >7.0</td>
#     </tr>
#   </tbody>
# </table>
# Right    9.666667
# Wrong    9.333333
# dtype: float64
# <style type="text/css">
# #T_e56ce_row0_col0, #T_e56ce_row1_col0, #T_e56ce_row2_col0, #T_e56ce_row2_col1, #T_e56ce_row3_col0, #T_e56ce_row3_col1, #T_e56ce_row4_col1, #T_e56ce_row5_col1, #T_e56ce_row6_col0, #T_e56ce_row7_col0, #T_e56ce_row7_col1, #T_e56ce_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e56ce_row0_col1, #T_e56ce_row1_col1, #T_e56ce_row4_col0, #T_e56ce_row5_col0, #T_e56ce_row6_col1, #T_e56ce_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e56ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e56ce_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_e56ce_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_e56ce_row0_col1" class="data row0 col1" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_e56ce_row1_col0" class="data row1 col0" >10.0</td>
#       <td id="T_e56ce_row1_col1" class="data row1 col1" >11.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_e56ce_row2_col0" class="data row2 col0" >8.0</td>
#       <td id="T_e56ce_row2_col1" class="data row2 col1" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_e56ce_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_e56ce_row3_col1" class="data row3 col1" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_e56ce_row4_col0" class="data row4 col0" >23.0</td>
#       <td id="T_e56ce_row4_col1" class="data row4 col1" >16.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_e56ce_row5_col0" class="data row5 col0" >17.0</td>
#       <td id="T_e56ce_row5_col1" class="data row5 col1" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_e56ce_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_e56ce_row6_col1" class="data row6 col1" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_e56ce_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_e56ce_row7_col1" class="data row7 col1" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_e56ce_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_e56ce_row8_col0" class="data row8 col0" >6.0</td>
#       <td id="T_e56ce_row8_col1" class="data row8 col1" >10.0</td>
#     </tr>
#   </tbody>
# </table>
# Right    9.666667
# Wrong    8.444444
# dtype: float64
# <style type="text/css">
# #T_d8bc9_row0_col0, #T_d8bc9_row1_col1, #T_d8bc9_row2_col1, #T_d8bc9_row3_col1, #T_d8bc9_row4_col1, #T_d8bc9_row5_col1, #T_d8bc9_row6_col0, #T_d8bc9_row7_col0, #T_d8bc9_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d8bc9_row0_col1, #T_d8bc9_row1_col0, #T_d8bc9_row2_col0, #T_d8bc9_row3_col0, #T_d8bc9_row4_col0, #T_d8bc9_row5_col0, #T_d8bc9_row6_col1, #T_d8bc9_row7_col1, #T_d8bc9_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d8bc9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8bc9_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_d8bc9_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_d8bc9_row0_col1" class="data row0 col1" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_d8bc9_row1_col0" class="data row1 col0" >11.0</td>
#       <td id="T_d8bc9_row1_col1" class="data row1 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_d8bc9_row2_col0" class="data row2 col0" >8.0</td>
#       <td id="T_d8bc9_row2_col1" class="data row2 col1" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_d8bc9_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_d8bc9_row3_col1" class="data row3 col1" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_d8bc9_row4_col0" class="data row4 col0" >22.0</td>
#       <td id="T_d8bc9_row4_col1" class="data row4 col1" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_d8bc9_row5_col0" class="data row5 col0" >16.0</td>
#       <td id="T_d8bc9_row5_col1" class="data row5 col1" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_d8bc9_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_d8bc9_row6_col1" class="data row6 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_d8bc9_row7_col0" class="data row7 col0" >7.0</td>
#       <td id="T_d8bc9_row7_col1" class="data row7 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_d8bc9_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_d8bc9_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_d8bc9_row8_col1" class="data row8 col1" >9.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
for resc,tvg in zip(resc_all_all,tvg_all_all):
    
    #hold=(resc+tvg)/2

    #with open(r"/home/users/fschreiber/project/data_frames/first words/"+typ+"_avg.p","wb") as f:
    #    pickle.dump(hold,f)
    
    #df=hold.style.format(precision=3).background_gradient(cmap="Blues",axis=1)
    #resc[resc.select_dtypes(include=['number']).columns] *= 100
    #tvg[tvg.select_dtypes(include=['number']).columns] *= 100

    df_resc=resc.style.format(precision=1).background_gradient(cmap="Blues",axis=1)
    df_tvg=tvg.style.format(precision=1).background_gradient(cmap="Blues",axis=1)
    
    display(df_resc)
    display(df_tvg)

#color_avg=(color_resc_df+color_tvg_df)/2

#df_typ=color_avg.style.format(precision=3).background_gradient(cmap="Blues",axis=1)
   
#df_typ
# Out:
# <style type="text/css">
# #T_1c847_row0_col0, #T_1c847_row1_col2, #T_1c847_row2_col0, #T_1c847_row2_col2, #T_1c847_row3_col0, #T_1c847_row4_col1, #T_1c847_row4_col2, #T_1c847_row6_col2, #T_1c847_row7_col2, #T_1c847_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1c847_row0_col1, #T_1c847_row1_col1, #T_1c847_row2_col1, #T_1c847_row3_col1, #T_1c847_row3_col2, #T_1c847_row4_col0, #T_1c847_row5_col0, #T_1c847_row5_col1, #T_1c847_row5_col2, #T_1c847_row6_col0, #T_1c847_row6_col1, #T_1c847_row7_col0, #T_1c847_row7_col1, #T_1c847_row8_col0, #T_1c847_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1c847_row0_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_1c847_row1_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c847_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c847_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_1c847_row0_col0" class="data row0 col0" >32.0</td>
#       <td id="T_1c847_row0_col1" class="data row0 col1" >23.0</td>
#       <td id="T_1c847_row0_col2" class="data row0 col2" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_1c847_row1_col0" class="data row1 col0" >20.0</td>
#       <td id="T_1c847_row1_col1" class="data row1 col1" >13.0</td>
#       <td id="T_1c847_row1_col2" class="data row1 col2" >21.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_1c847_row2_col0" class="data row2 col0" >25.0</td>
#       <td id="T_1c847_row2_col1" class="data row2 col1" >19.0</td>
#       <td id="T_1c847_row2_col2" class="data row2 col2" >25.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_1c847_row3_col0" class="data row3 col0" >6.0</td>
#       <td id="T_1c847_row3_col1" class="data row3 col1" >5.0</td>
#       <td id="T_1c847_row3_col2" class="data row3 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_1c847_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_1c847_row4_col1" class="data row4 col1" >3.0</td>
#       <td id="T_1c847_row4_col2" class="data row4 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_1c847_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_1c847_row5_col1" class="data row5 col1" >4.0</td>
#       <td id="T_1c847_row5_col2" class="data row5 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_1c847_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_1c847_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_1c847_row6_col2" class="data row6 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_1c847_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_1c847_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_1c847_row7_col2" class="data row7 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_1c847_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_1c847_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_1c847_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_1c847_row8_col2" class="data row8 col2" >5.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f7cae_row0_col0, #T_f7cae_row1_col0, #T_f7cae_row1_col2, #T_f7cae_row2_col0, #T_f7cae_row3_col0, #T_f7cae_row4_col1, #T_f7cae_row4_col2, #T_f7cae_row6_col2, #T_f7cae_row7_col2, #T_f7cae_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f7cae_row0_col1, #T_f7cae_row1_col1, #T_f7cae_row2_col1, #T_f7cae_row3_col1, #T_f7cae_row4_col0, #T_f7cae_row5_col0, #T_f7cae_row5_col1, #T_f7cae_row5_col2, #T_f7cae_row6_col0, #T_f7cae_row6_col1, #T_f7cae_row7_col0, #T_f7cae_row7_col1, #T_f7cae_row8_col0, #T_f7cae_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f7cae_row0_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_f7cae_row2_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_f7cae_row3_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# </style>
# <table id="T_f7cae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7cae_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_f7cae_row0_col0" class="data row0 col0" >33.0</td>
#       <td id="T_f7cae_row0_col1" class="data row0 col1" >22.0</td>
#       <td id="T_f7cae_row0_col2" class="data row0 col2" >29.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_f7cae_row1_col0" class="data row1 col0" >20.0</td>
#       <td id="T_f7cae_row1_col1" class="data row1 col1" >13.0</td>
#       <td id="T_f7cae_row1_col2" class="data row1 col2" >20.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_f7cae_row2_col0" class="data row2 col0" >25.0</td>
#       <td id="T_f7cae_row2_col1" class="data row2 col1" >18.0</td>
#       <td id="T_f7cae_row2_col2" class="data row2 col2" >24.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_f7cae_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_f7cae_row3_col1" class="data row3 col1" >4.0</td>
#       <td id="T_f7cae_row3_col2" class="data row3 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_f7cae_row4_col0" class="data row4 col0" >2.0</td>
#       <td id="T_f7cae_row4_col1" class="data row4 col1" >3.0</td>
#       <td id="T_f7cae_row4_col2" class="data row4 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_f7cae_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_f7cae_row5_col1" class="data row5 col1" >4.0</td>
#       <td id="T_f7cae_row5_col2" class="data row5 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_f7cae_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_f7cae_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_f7cae_row6_col2" class="data row6 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_f7cae_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_f7cae_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_f7cae_row7_col2" class="data row7 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_f7cae_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_f7cae_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_f7cae_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_f7cae_row8_col2" class="data row8 col2" >5.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_954cd_row0_col0, #T_954cd_row1_col0, #T_954cd_row2_col0, #T_954cd_row3_col0, #T_954cd_row4_col0, #T_954cd_row5_col0, #T_954cd_row6_col0, #T_954cd_row6_col1, #T_954cd_row6_col2, #T_954cd_row7_col0, #T_954cd_row7_col1, #T_954cd_row7_col2, #T_954cd_row8_col0, #T_954cd_row8_col1, #T_954cd_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_954cd_row0_col1, #T_954cd_row1_col1, #T_954cd_row2_col1, #T_954cd_row3_col1, #T_954cd_row3_col2, #T_954cd_row4_col1, #T_954cd_row4_col2, #T_954cd_row5_col1, #T_954cd_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_954cd_row0_col2, #T_954cd_row1_col2, #T_954cd_row2_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_954cd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Relative Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_954cd_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_954cd_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_954cd_row0_col1" class="data row0 col1" >4.0</td>
#       <td id="T_954cd_row0_col2" class="data row0 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_954cd_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_954cd_row1_col1" class="data row1 col1" >4.0</td>
#       <td id="T_954cd_row1_col2" class="data row1 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_954cd_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_954cd_row2_col1" class="data row2 col1" >4.0</td>
#       <td id="T_954cd_row2_col2" class="data row2 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_954cd_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_954cd_row3_col1" class="data row3 col1" >6.0</td>
#       <td id="T_954cd_row3_col2" class="data row3 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_954cd_row4_col0" class="data row4 col0" >4.0</td>
#       <td id="T_954cd_row4_col1" class="data row4 col1" >6.0</td>
#       <td id="T_954cd_row4_col2" class="data row4 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_954cd_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_954cd_row5_col1" class="data row5 col1" >6.0</td>
#       <td id="T_954cd_row5_col2" class="data row5 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_954cd_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_954cd_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_954cd_row6_col2" class="data row6 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_954cd_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_954cd_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_954cd_row7_col2" class="data row7 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_954cd_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_954cd_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_954cd_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_954cd_row8_col2" class="data row8 col2" >4.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cc0dc_row0_col0, #T_cc0dc_row1_col0, #T_cc0dc_row2_col0, #T_cc0dc_row3_col0, #T_cc0dc_row4_col0, #T_cc0dc_row5_col0, #T_cc0dc_row6_col0, #T_cc0dc_row6_col1, #T_cc0dc_row6_col2, #T_cc0dc_row7_col0, #T_cc0dc_row7_col1, #T_cc0dc_row7_col2, #T_cc0dc_row8_col0, #T_cc0dc_row8_col1, #T_cc0dc_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cc0dc_row0_col1, #T_cc0dc_row1_col1, #T_cc0dc_row2_col1, #T_cc0dc_row3_col1, #T_cc0dc_row3_col2, #T_cc0dc_row4_col1, #T_cc0dc_row5_col1, #T_cc0dc_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cc0dc_row0_col2, #T_cc0dc_row1_col2, #T_cc0dc_row2_col2, #T_cc0dc_row4_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cc0dc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Relative Position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc0dc_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_cc0dc_row0_col0" class="data row0 col0" >2.0</td>
#       <td id="T_cc0dc_row0_col1" class="data row0 col1" >4.0</td>
#       <td id="T_cc0dc_row0_col2" class="data row0 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_cc0dc_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_cc0dc_row1_col1" class="data row1 col1" >4.0</td>
#       <td id="T_cc0dc_row1_col2" class="data row1 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_cc0dc_row2_col0" class="data row2 col0" >2.0</td>
#       <td id="T_cc0dc_row2_col1" class="data row2 col1" >4.0</td>
#       <td id="T_cc0dc_row2_col2" class="data row2 col2" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_cc0dc_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_cc0dc_row3_col1" class="data row3 col1" >6.0</td>
#       <td id="T_cc0dc_row3_col2" class="data row3 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_cc0dc_row4_col0" class="data row4 col0" >4.0</td>
#       <td id="T_cc0dc_row4_col1" class="data row4 col1" >6.0</td>
#       <td id="T_cc0dc_row4_col2" class="data row4 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_cc0dc_row5_col0" class="data row5 col0" >4.0</td>
#       <td id="T_cc0dc_row5_col1" class="data row5 col1" >6.0</td>
#       <td id="T_cc0dc_row5_col2" class="data row5 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_cc0dc_row6_col0" class="data row6 col0" >4.0</td>
#       <td id="T_cc0dc_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_cc0dc_row6_col2" class="data row6 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_cc0dc_row7_col0" class="data row7 col0" >4.0</td>
#       <td id="T_cc0dc_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_cc0dc_row7_col2" class="data row7 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_cc0dc_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_cc0dc_row8_col0" class="data row8 col0" >4.0</td>
#       <td id="T_cc0dc_row8_col1" class="data row8 col1" >4.0</td>
#       <td id="T_cc0dc_row8_col2" class="data row8 col2" >4.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_90731_row0_col0, #T_90731_row0_col1, #T_90731_row1_col1, #T_90731_row2_col0, #T_90731_row2_col1, #T_90731_row3_col0, #T_90731_row4_col0, #T_90731_row5_col0, #T_90731_row6_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_90731_row0_col2, #T_90731_row1_col0, #T_90731_row1_col2, #T_90731_row2_col2, #T_90731_row3_col2, #T_90731_row4_col1, #T_90731_row5_col1, #T_90731_row6_col0, #T_90731_row6_col2, #T_90731_row7_col0, #T_90731_row7_col1, #T_90731_row7_col2, #T_90731_row8_col0, #T_90731_row8_col1, #T_90731_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_90731_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_90731_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_90731_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# </style>
# <table id="T_90731_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90731_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_90731_row0_col0" class="data row0 col0" >6.0</td>
#       <td id="T_90731_row0_col1" class="data row0 col1" >6.0</td>
#       <td id="T_90731_row0_col2" class="data row0 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_90731_row1_col0" class="data row1 col0" >8.0</td>
#       <td id="T_90731_row1_col1" class="data row1 col1" >9.0</td>
#       <td id="T_90731_row1_col2" class="data row1 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_90731_row2_col0" class="data row2 col0" >8.0</td>
#       <td id="T_90731_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_90731_row2_col2" class="data row2 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_90731_row3_col0" class="data row3 col0" >11.0</td>
#       <td id="T_90731_row3_col1" class="data row3 col1" >9.0</td>
#       <td id="T_90731_row3_col2" class="data row3 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_90731_row4_col0" class="data row4 col0" >15.0</td>
#       <td id="T_90731_row4_col1" class="data row4 col1" >12.0</td>
#       <td id="T_90731_row4_col2" class="data row4 col2" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_90731_row5_col0" class="data row5 col0" >14.0</td>
#       <td id="T_90731_row5_col1" class="data row5 col1" >9.0</td>
#       <td id="T_90731_row5_col2" class="data row5 col2" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_90731_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_90731_row6_col1" class="data row6 col1" >7.0</td>
#       <td id="T_90731_row6_col2" class="data row6 col2" >6.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_90731_row7_col0" class="data row7 col0" >7.0</td>
#       <td id="T_90731_row7_col1" class="data row7 col1" >7.0</td>
#       <td id="T_90731_row7_col2" class="data row7 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_90731_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_90731_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_90731_row8_col1" class="data row8 col1" >7.0</td>
#       <td id="T_90731_row8_col2" class="data row8 col2" >7.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b20de_row0_col0, #T_b20de_row0_col1, #T_b20de_row1_col1, #T_b20de_row2_col1, #T_b20de_row3_col0, #T_b20de_row4_col0, #T_b20de_row5_col0, #T_b20de_row6_col1, #T_b20de_row6_col2, #T_b20de_row7_col1, #T_b20de_row7_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b20de_row0_col2, #T_b20de_row1_col0, #T_b20de_row1_col2, #T_b20de_row2_col0, #T_b20de_row2_col2, #T_b20de_row3_col1, #T_b20de_row3_col2, #T_b20de_row4_col1, #T_b20de_row5_col1, #T_b20de_row6_col0, #T_b20de_row7_col0, #T_b20de_row8_col0, #T_b20de_row8_col1, #T_b20de_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b20de_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_b20de_row5_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# </style>
# <table id="T_b20de_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Color</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b20de_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_b20de_row0_col0" class="data row0 col0" >6.0</td>
#       <td id="T_b20de_row0_col1" class="data row0 col1" >6.0</td>
#       <td id="T_b20de_row0_col2" class="data row0 col2" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_b20de_row1_col0" class="data row1 col0" >8.0</td>
#       <td id="T_b20de_row1_col1" class="data row1 col1" >9.0</td>
#       <td id="T_b20de_row1_col2" class="data row1 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_b20de_row2_col0" class="data row2 col0" >7.0</td>
#       <td id="T_b20de_row2_col1" class="data row2 col1" >8.0</td>
#       <td id="T_b20de_row2_col2" class="data row2 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_b20de_row3_col0" class="data row3 col0" >11.0</td>
#       <td id="T_b20de_row3_col1" class="data row3 col1" >8.0</td>
#       <td id="T_b20de_row3_col2" class="data row3 col2" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_b20de_row4_col0" class="data row4 col0" >16.0</td>
#       <td id="T_b20de_row4_col1" class="data row4 col1" >10.0</td>
#       <td id="T_b20de_row4_col2" class="data row4 col2" >12.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_b20de_row5_col0" class="data row5 col0" >15.0</td>
#       <td id="T_b20de_row5_col1" class="data row5 col1" >9.0</td>
#       <td id="T_b20de_row5_col2" class="data row5 col2" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_b20de_row6_col0" class="data row6 col0" >6.0</td>
#       <td id="T_b20de_row6_col1" class="data row6 col1" >7.0</td>
#       <td id="T_b20de_row6_col2" class="data row6 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_b20de_row7_col0" class="data row7 col0" >6.0</td>
#       <td id="T_b20de_row7_col1" class="data row7 col1" >7.0</td>
#       <td id="T_b20de_row7_col2" class="data row7 col2" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_b20de_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_b20de_row8_col0" class="data row8 col0" >7.0</td>
#       <td id="T_b20de_row8_col1" class="data row8 col1" >7.0</td>
#       <td id="T_b20de_row8_col2" class="data row8 col2" >7.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d075d_row0_col0, #T_d075d_row0_col2, #T_d075d_row1_col0, #T_d075d_row2_col0, #T_d075d_row2_col1, #T_d075d_row3_col0, #T_d075d_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d075d_row0_col1, #T_d075d_row1_col1, #T_d075d_row1_col2, #T_d075d_row2_col2, #T_d075d_row3_col2, #T_d075d_row4_col0, #T_d075d_row4_col1, #T_d075d_row4_col2, #T_d075d_row5_col1, #T_d075d_row5_col2, #T_d075d_row6_col0, #T_d075d_row6_col1, #T_d075d_row6_col2, #T_d075d_row7_col0, #T_d075d_row7_col1, #T_d075d_row7_col2, #T_d075d_row8_col0, #T_d075d_row8_col1, #T_d075d_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d075d_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d075d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d075d_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_d075d_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_d075d_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_d075d_row0_col2" class="data row0 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_d075d_row1_col0" class="data row1 col0" >1.0</td>
#       <td id="T_d075d_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_d075d_row1_col2" class="data row1 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_d075d_row2_col0" class="data row2 col0" >1.0</td>
#       <td id="T_d075d_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_d075d_row2_col2" class="data row2 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_d075d_row3_col0" class="data row3 col0" >3.0</td>
#       <td id="T_d075d_row3_col1" class="data row3 col1" >2.0</td>
#       <td id="T_d075d_row3_col2" class="data row3 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_d075d_row4_col0" class="data row4 col0" >1.0</td>
#       <td id="T_d075d_row4_col1" class="data row4 col1" >1.0</td>
#       <td id="T_d075d_row4_col2" class="data row4 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_d075d_row5_col0" class="data row5 col0" >2.0</td>
#       <td id="T_d075d_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_d075d_row5_col2" class="data row5 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_d075d_row6_col0" class="data row6 col0" >1.0</td>
#       <td id="T_d075d_row6_col1" class="data row6 col1" >1.0</td>
#       <td id="T_d075d_row6_col2" class="data row6 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_d075d_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_d075d_row7_col1" class="data row7 col1" >1.0</td>
#       <td id="T_d075d_row7_col2" class="data row7 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_d075d_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_d075d_row8_col0" class="data row8 col0" >1.0</td>
#       <td id="T_d075d_row8_col1" class="data row8 col1" >1.0</td>
#       <td id="T_d075d_row8_col2" class="data row8 col2" >1.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_85ab1_row0_col0, #T_85ab1_row0_col1, #T_85ab1_row0_col2, #T_85ab1_row1_col1, #T_85ab1_row1_col2, #T_85ab1_row2_col2, #T_85ab1_row3_col1, #T_85ab1_row3_col2, #T_85ab1_row4_col0, #T_85ab1_row4_col1, #T_85ab1_row4_col2, #T_85ab1_row5_col1, #T_85ab1_row5_col2, #T_85ab1_row6_col0, #T_85ab1_row6_col1, #T_85ab1_row6_col2, #T_85ab1_row7_col0, #T_85ab1_row7_col1, #T_85ab1_row7_col2, #T_85ab1_row8_col0, #T_85ab1_row8_col1, #T_85ab1_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_85ab1_row1_col0, #T_85ab1_row2_col0, #T_85ab1_row2_col1, #T_85ab1_row3_col0, #T_85ab1_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_85ab1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85ab1_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_85ab1_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_85ab1_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_85ab1_row0_col2" class="data row0 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_85ab1_row1_col0" class="data row1 col0" >1.0</td>
#       <td id="T_85ab1_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_85ab1_row1_col2" class="data row1 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_85ab1_row2_col0" class="data row2 col0" >1.0</td>
#       <td id="T_85ab1_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_85ab1_row2_col2" class="data row2 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_85ab1_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_85ab1_row3_col1" class="data row3 col1" >1.0</td>
#       <td id="T_85ab1_row3_col2" class="data row3 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_85ab1_row4_col0" class="data row4 col0" >1.0</td>
#       <td id="T_85ab1_row4_col1" class="data row4 col1" >1.0</td>
#       <td id="T_85ab1_row4_col2" class="data row4 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_85ab1_row5_col0" class="data row5 col0" >3.0</td>
#       <td id="T_85ab1_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_85ab1_row5_col2" class="data row5 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_85ab1_row6_col0" class="data row6 col0" >1.0</td>
#       <td id="T_85ab1_row6_col1" class="data row6 col1" >1.0</td>
#       <td id="T_85ab1_row6_col2" class="data row6 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_85ab1_row7_col0" class="data row7 col0" >1.0</td>
#       <td id="T_85ab1_row7_col1" class="data row7 col1" >1.0</td>
#       <td id="T_85ab1_row7_col2" class="data row7 col2" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_85ab1_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_85ab1_row8_col0" class="data row8 col0" >1.0</td>
#       <td id="T_85ab1_row8_col1" class="data row8 col1" >1.0</td>
#       <td id="T_85ab1_row8_col2" class="data row8 col2" >1.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_964a1_row0_col0, #T_964a1_row1_col0, #T_964a1_row2_col0, #T_964a1_row3_col0, #T_964a1_row4_col0, #T_964a1_row5_col0, #T_964a1_row6_col0, #T_964a1_row6_col1, #T_964a1_row7_col0, #T_964a1_row7_col1, #T_964a1_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_964a1_row0_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_964a1_row0_col2, #T_964a1_row1_col2, #T_964a1_row2_col2, #T_964a1_row3_col2, #T_964a1_row4_col2, #T_964a1_row5_col2, #T_964a1_row6_col2, #T_964a1_row7_col2, #T_964a1_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_964a1_row1_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_964a1_row2_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_964a1_row3_col1, #T_964a1_row8_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_964a1_row4_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_964a1_row5_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_964a1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Stopwords</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_964a1_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_964a1_row0_col0" class="data row0 col0" >19.0</td>
#       <td id="T_964a1_row0_col1" class="data row0 col1" >27.0</td>
#       <td id="T_964a1_row0_col2" class="data row0 col2" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_964a1_row1_col0" class="data row1 col0" >24.0</td>
#       <td id="T_964a1_row1_col1" class="data row1 col1" >27.0</td>
#       <td id="T_964a1_row1_col2" class="data row1 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_964a1_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_964a1_row2_col1" class="data row2 col1" >28.0</td>
#       <td id="T_964a1_row2_col2" class="data row2 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_964a1_row3_col0" class="data row3 col0" >22.0</td>
#       <td id="T_964a1_row3_col1" class="data row3 col1" >27.0</td>
#       <td id="T_964a1_row3_col2" class="data row3 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_964a1_row4_col0" class="data row4 col0" >23.0</td>
#       <td id="T_964a1_row4_col1" class="data row4 col1" >25.0</td>
#       <td id="T_964a1_row4_col2" class="data row4 col2" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_964a1_row5_col0" class="data row5 col0" >21.0</td>
#       <td id="T_964a1_row5_col1" class="data row5 col1" >27.0</td>
#       <td id="T_964a1_row5_col2" class="data row5 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_964a1_row6_col0" class="data row6 col0" >43.0</td>
#       <td id="T_964a1_row6_col1" class="data row6 col1" >43.0</td>
#       <td id="T_964a1_row6_col2" class="data row6 col2" >46.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_964a1_row7_col0" class="data row7 col0" >43.0</td>
#       <td id="T_964a1_row7_col1" class="data row7 col1" >43.0</td>
#       <td id="T_964a1_row7_col2" class="data row7 col2" >45.0</td>
#     </tr>
#     <tr>
#       <th id="T_964a1_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_964a1_row8_col0" class="data row8 col0" >42.0</td>
#       <td id="T_964a1_row8_col1" class="data row8 col1" >44.0</td>
#       <td id="T_964a1_row8_col2" class="data row8 col2" >46.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3488e_row0_col0, #T_3488e_row1_col0, #T_3488e_row2_col0, #T_3488e_row3_col0, #T_3488e_row4_col0, #T_3488e_row5_col0, #T_3488e_row6_col0, #T_3488e_row7_col0, #T_3488e_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3488e_row0_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_3488e_row0_col2, #T_3488e_row1_col2, #T_3488e_row2_col2, #T_3488e_row3_col2, #T_3488e_row4_col2, #T_3488e_row5_col2, #T_3488e_row6_col2, #T_3488e_row7_col2, #T_3488e_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3488e_row1_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_3488e_row2_col1, #T_3488e_row8_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3488e_row3_col1, #T_3488e_row5_col1, #T_3488e_row6_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3488e_row4_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_3488e_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3488e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Stopwords</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3488e_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_3488e_row0_col0" class="data row0 col0" >18.0</td>
#       <td id="T_3488e_row0_col1" class="data row0 col1" >27.0</td>
#       <td id="T_3488e_row0_col2" class="data row0 col2" >29.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_3488e_row1_col0" class="data row1 col0" >23.0</td>
#       <td id="T_3488e_row1_col1" class="data row1 col1" >26.0</td>
#       <td id="T_3488e_row1_col2" class="data row1 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_3488e_row2_col0" class="data row2 col0" >21.0</td>
#       <td id="T_3488e_row2_col1" class="data row2 col1" >27.0</td>
#       <td id="T_3488e_row2_col2" class="data row2 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_3488e_row3_col0" class="data row3 col0" >21.0</td>
#       <td id="T_3488e_row3_col1" class="data row3 col1" >26.0</td>
#       <td id="T_3488e_row3_col2" class="data row3 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_3488e_row4_col0" class="data row4 col0" >22.0</td>
#       <td id="T_3488e_row4_col1" class="data row4 col1" >24.0</td>
#       <td id="T_3488e_row4_col2" class="data row4 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_3488e_row5_col0" class="data row5 col0" >21.0</td>
#       <td id="T_3488e_row5_col1" class="data row5 col1" >26.0</td>
#       <td id="T_3488e_row5_col2" class="data row5 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_3488e_row6_col0" class="data row6 col0" >43.0</td>
#       <td id="T_3488e_row6_col1" class="data row6 col1" >44.0</td>
#       <td id="T_3488e_row6_col2" class="data row6 col2" >45.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_3488e_row7_col0" class="data row7 col0" >42.0</td>
#       <td id="T_3488e_row7_col1" class="data row7 col1" >44.0</td>
#       <td id="T_3488e_row7_col2" class="data row7 col2" >45.0</td>
#     </tr>
#     <tr>
#       <th id="T_3488e_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_3488e_row8_col0" class="data row8 col0" >41.0</td>
#       <td id="T_3488e_row8_col1" class="data row8 col1" >44.0</td>
#       <td id="T_3488e_row8_col2" class="data row8 col2" >46.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_98c53_row0_col0, #T_98c53_row0_col1, #T_98c53_row1_col1, #T_98c53_row2_col0, #T_98c53_row3_col0, #T_98c53_row4_col0, #T_98c53_row5_col0, #T_98c53_row6_col0, #T_98c53_row7_col0, #T_98c53_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_98c53_row0_col2, #T_98c53_row1_col2, #T_98c53_row2_col2, #T_98c53_row3_col2, #T_98c53_row4_col2, #T_98c53_row5_col2, #T_98c53_row6_col2, #T_98c53_row7_col2, #T_98c53_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_98c53_row1_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_98c53_row2_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_98c53_row3_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_98c53_row4_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_98c53_row5_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_98c53_row6_col1, #T_98c53_row7_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_98c53_row8_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# </style>
# <table id="T_98c53_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rest</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98c53_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_98c53_row0_col0" class="data row0 col0" >40.0</td>
#       <td id="T_98c53_row0_col1" class="data row0 col1" >40.0</td>
#       <td id="T_98c53_row0_col2" class="data row0 col2" >33.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_98c53_row1_col0" class="data row1 col0" >45.0</td>
#       <td id="T_98c53_row1_col1" class="data row1 col1" >46.0</td>
#       <td id="T_98c53_row1_col2" class="data row1 col2" >36.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_98c53_row2_col0" class="data row2 col0" >43.0</td>
#       <td id="T_98c53_row2_col1" class="data row2 col1" >42.0</td>
#       <td id="T_98c53_row2_col2" class="data row2 col2" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_98c53_row3_col0" class="data row3 col0" >53.0</td>
#       <td id="T_98c53_row3_col1" class="data row3 col1" >52.0</td>
#       <td id="T_98c53_row3_col2" class="data row3 col2" >49.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_98c53_row4_col0" class="data row4 col0" >55.0</td>
#       <td id="T_98c53_row4_col1" class="data row4 col1" >54.0</td>
#       <td id="T_98c53_row4_col2" class="data row4 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_98c53_row5_col0" class="data row5 col0" >54.0</td>
#       <td id="T_98c53_row5_col1" class="data row5 col1" >53.0</td>
#       <td id="T_98c53_row5_col2" class="data row5 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_98c53_row6_col0" class="data row6 col0" >42.0</td>
#       <td id="T_98c53_row6_col1" class="data row6 col1" >40.0</td>
#       <td id="T_98c53_row6_col2" class="data row6 col2" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_98c53_row7_col0" class="data row7 col0" >42.0</td>
#       <td id="T_98c53_row7_col1" class="data row7 col1" >40.0</td>
#       <td id="T_98c53_row7_col2" class="data row7 col2" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_98c53_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_98c53_row8_col0" class="data row8 col0" >42.0</td>
#       <td id="T_98c53_row8_col1" class="data row8 col1" >40.0</td>
#       <td id="T_98c53_row8_col2" class="data row8 col2" >39.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_aa512_row0_col0, #T_aa512_row0_col1, #T_aa512_row1_col1, #T_aa512_row2_col0, #T_aa512_row3_col1, #T_aa512_row4_col0, #T_aa512_row4_col1, #T_aa512_row5_col0, #T_aa512_row5_col1, #T_aa512_row6_col0, #T_aa512_row7_col0, #T_aa512_row8_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_aa512_row0_col2, #T_aa512_row1_col2, #T_aa512_row2_col2, #T_aa512_row3_col2, #T_aa512_row4_col2, #T_aa512_row5_col2, #T_aa512_row6_col2, #T_aa512_row7_col2, #T_aa512_row8_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_aa512_row1_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_aa512_row2_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_aa512_row3_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_aa512_row6_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_aa512_row7_col1, #T_aa512_row8_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# </style>
# <table id="T_aa512_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Right</th>
#       <th class="col_heading level0 col1" >Wrong</th>
#       <th class="col_heading level0 col2" >Mixed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rest</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa512_level0_row0" class="row_heading level0 row0" >unc testB</th>
#       <td id="T_aa512_row0_col0" class="data row0 col0" >40.0</td>
#       <td id="T_aa512_row0_col1" class="data row0 col1" >40.0</td>
#       <td id="T_aa512_row0_col2" class="data row0 col2" >33.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row1" class="row_heading level0 row1" >unc testA</th>
#       <td id="T_aa512_row1_col0" class="data row1 col0" >45.0</td>
#       <td id="T_aa512_row1_col1" class="data row1 col1" >47.0</td>
#       <td id="T_aa512_row1_col2" class="data row1 col2" >36.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row2" class="row_heading level0 row2" >unc val</th>
#       <td id="T_aa512_row2_col0" class="data row2 col0" >43.0</td>
#       <td id="T_aa512_row2_col1" class="data row2 col1" >42.0</td>
#       <td id="T_aa512_row2_col2" class="data row2 col2" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row3" class="row_heading level0 row3" >unc+ testB</th>
#       <td id="T_aa512_row3_col0" class="data row3 col0" >53.0</td>
#       <td id="T_aa512_row3_col1" class="data row3 col1" >54.0</td>
#       <td id="T_aa512_row3_col2" class="data row3 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row4" class="row_heading level0 row4" >unc+ testA</th>
#       <td id="T_aa512_row4_col0" class="data row4 col0" >55.0</td>
#       <td id="T_aa512_row4_col1" class="data row4 col1" >55.0</td>
#       <td id="T_aa512_row4_col2" class="data row4 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row5" class="row_heading level0 row5" >unc+ val</th>
#       <td id="T_aa512_row5_col0" class="data row5 col0" >54.0</td>
#       <td id="T_aa512_row5_col1" class="data row5 col1" >54.0</td>
#       <td id="T_aa512_row5_col2" class="data row5 col2" >48.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row6" class="row_heading level0 row6" >gref_umd test</th>
#       <td id="T_aa512_row6_col0" class="data row6 col0" >42.0</td>
#       <td id="T_aa512_row6_col1" class="data row6 col1" >40.0</td>
#       <td id="T_aa512_row6_col2" class="data row6 col2" >38.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row7" class="row_heading level0 row7" >gref_umd val</th>
#       <td id="T_aa512_row7_col0" class="data row7 col0" >43.0</td>
#       <td id="T_aa512_row7_col1" class="data row7 col1" >40.0</td>
#       <td id="T_aa512_row7_col2" class="data row7 col2" >39.0</td>
#     </tr>
#     <tr>
#       <th id="T_aa512_level0_row8" class="row_heading level0 row8" >gref val</th>
#       <td id="T_aa512_row8_col0" class="data row8 col0" >43.0</td>
#       <td id="T_aa512_row8_col1" class="data row8 col1" >40.0</td>
#       <td id="T_aa512_row8_col2" class="data row8 col2" >39.0</td>
#     </tr>
#   </tbody>
# </table>
